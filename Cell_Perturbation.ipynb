# %% [markdown]
# # Multi-task learning from cell line perturbation

# %% [markdown]
# * Authors: Eshika Saxena, Doris Fu
# * Objective: Implement and train multi-task classifier model to predict positive/negative cell viability score from encoded cell line RNA-seq profile. Fine-tune the pre-trained multi-task classifier model on patient data for patient long/short term pfs classification.

# %% [markdown]
# ## Load libraries

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

import os 
import shutil

import copy

import tensorflow as tf
import tensorflow.keras as K

from itertools import cycle

from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

from utils import CCLE_utils
from utils import MMRF_utils

# %%
np.random.seed(0)
tf.random.set_seed(221)
tf.compat.v1.reset_default_graph()

# %%
# directory containing raw CCLE and MMRF data
data_dir = '/Users/eshikasaxena/Documents/MLHC/mm-cell_lines/data/'

# %% [markdown]
# ## Load embeddings for cell line (CCLE) data from AE trained on MMRF data

# %%
with pd.HDFStore('./autoencoder_embeddings/normalized_embeddings_128.h5') as store:
    print(store.keys())
# Out:
# ['/ccle_test_ccleae', '/ccle_test_combinedae', '/ccle_test_mmrfae', '/ccle_train_ccleae', '/ccle_train_combinedae', '/ccle_train_mmrfae', '/ccle_valid_ccleae', '/ccle_valid_combinedae', '/ccle_valid_mmrfae', '/mmrf_test_ccleae', '/mmrf_test_combinedae', '/mmrf_test_mmrfae', '/mmrf_train_ccleae', '/mmrf_train_combinedae', '/mmrf_train_mmrfae', '/mmrf_valid_ccleae', '/mmrf_valid_combinedae', '/mmrf_valid_mmrfae']

# %%
X_train = pd.read_hdf('./autoencoder_embeddings/normalized_embeddings_128.h5', key = 'ccle_train_mmrfae', index_col=1)
X_train = X_train.set_index(X_train.iloc[:, 0])
X_train = X_train.iloc[: , 1:]

X_val = pd.read_hdf('./autoencoder_embeddings/normalized_embeddings_128.h5', key = 'ccle_valid_mmrfae', index_col=1)
X_val = X_val.set_index(X_val.iloc[:, 0])
X_val = X_val.iloc[: , 1:]

X_test = pd.read_hdf('./autoencoder_embeddings/normalized_embeddings_128.h5', key = 'ccle_test_mmrfae', index_col=1)
X_test = X_test.set_index(X_test.iloc[:, 0])
X_test = X_test.iloc[: , 1:]

# %%
print('AE Embeddings for cell line data')
print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# AE Embeddings for cell line data
# (964, 128) (138, 128) (276, 128)

# %% [markdown]
# ## Load and preprocess cell viability data

# %% [markdown]
# * Only keep IDs that are in both RNA-seq and CRISPR knockout.
# * Restrict knockout cell viability scores to 13 genes of interest.
# * Only keep RNA seq cols that map to Ensembl IDs.

# %%
rnaseq = pd.read_csv(os.path.join(data_dir,'CCLE_expression.csv'))
rnaseq = rnaseq.rename(columns={'Unnamed: 0': 'DepMap_ID'})

crispr = pd.read_csv(os.path.join(data_dir,'Achilles_gene_effect.csv'))

# %%
ids = list(set(crispr.DepMap_ID).intersection(set(rnaseq.DepMap_ID)))

print(len(ids))
# Out:
# 800

# %%
# genes of interest
genes = [col for col in crispr.columns if 'PSMB' in col or 'IKZF1' in col or 'IKZF3' in col]

print(len(genes))
print(genes)
# Out:
# 13
# ['IKZF1 (10320)', 'IKZF3 (22806)', 'PSMB1 (5689)', 'PSMB10 (5699)', 'PSMB11 (122706)', 'PSMB2 (5690)', 'PSMB3 (5691)', 'PSMB4 (5692)', 'PSMB5 (5693)', 'PSMB6 (5694)', 'PSMB7 (5695)', 'PSMB8 (5696)', 'PSMB9 (5698)']

# %%
crispr = crispr[crispr.DepMap_ID.isin(ids)][genes + ['DepMap_ID']]

print(len(crispr))
print(len(crispr.columns))
# Out:
# 800
# 14

# %%
mapping = pd.read_csv('./utils/Ensembl_HGNC_map_042421.csv')
cols_to_keep = ['DepMap_ID'] + list(mapping.HGNC_ID) 
rnaseq = rnaseq[cols_to_keep]
rnaseq = rnaseq[rnaseq.DepMap_ID.isin(ids)]

print(len(rnaseq))
# Out:
# 800

# %%
crispr_rnaseq_merged = rnaseq.merge(crispr, on='DepMap_ID')
print(len(crispr_rnaseq_merged))
# Out:
# 800

# %%
crispr_rnaseq_merged = crispr_rnaseq_merged.set_index(['DepMap_ID'])
response_cols = [col for col in crispr_rnaseq_merged.columns if '_y' in col]
crispr = crispr_rnaseq_merged[response_cols]

print(len(crispr))
# Out:
# 800

# %% [markdown]
# ## Preprocess and format cell line data for model training

# %% [markdown]
# * Limit to IDs present in both RNA-seq and in cell viability data
# * Convert cell viability scores to binary
# * One-hot encode binary outcomes

# %%
train_index = list(set(X_train.index).intersection(crispr.index))
val_index = list(set(X_val.index).intersection(crispr.index))
test_index = list(set(X_test.index).intersection(crispr.index))

# %%
X_train = X_train.loc[train_index]
X_val = X_val.loc[val_index]
X_test = X_test.loc[test_index]

# %%
Y_train = crispr.loc[train_index]
Y_val = crispr.loc[val_index]
Y_test = crispr.loc[test_index]

# binary outcome used for classifier; positive = 1, negative = 0
bY_train = (Y_train >0).astype(int)
bY_val = (Y_val >0).astype(int)
bY_test = (Y_test >0).astype(int)

# onehot encode binary outcomes
bY_train_oneHot = K.utils.to_categorical(bY_train, 2)
bY_val_oneHot = K.utils.to_categorical(bY_val, 2)
bY_test_oneHot = K.utils.to_categorical(bY_test, 2)

# %%
print('CCLE RNA-seq and Cell Viability Data')
print('Train', X_train.shape, bY_train_oneHot.shape)
print('Val', X_val.shape, bY_val_oneHot.shape)
print('Test', X_test.shape, bY_test_oneHot.shape)
# Out:
# CCLE RNA-seq and Cell Viability Data
# Train (559, 128) (559, 13, 2)
# Val (77, 128) (77, 13, 2)
# Test (165, 128) (165, 13, 2)

# %% [markdown]
# ## Load embeddings for patient (MMRF) data from AE trained on MMRF data

# %%
X_train_pt = pd.read_hdf('./autoencoder_embeddings/normalized_embeddings_128.h5', key = 'mmrf_train_mmrfae', index_col=1)
X_train_pt = X_train_pt.set_index(X_train_pt.iloc[:, 0])
X_train_pt = X_train_pt.iloc[: , 1:]

X_val_pt = pd.read_hdf('./autoencoder_embeddings/normalized_embeddings_128.h5', key = 'mmrf_valid_mmrfae', index_col=1)
X_val_pt = X_val_pt.set_index(X_val_pt.iloc[:, 0])
X_val_pt = X_val_pt.iloc[: , 1:]

X_test_pt = pd.read_hdf('./autoencoder_embeddings/normalized_embeddings_128.h5', key = 'mmrf_test_mmrfae', index_col=1)
X_test_pt = X_test_pt.set_index(X_test_pt.iloc[:, 0])
X_test_pt = X_test_pt.iloc[: , 1:]

# %%
print('AE Embeddings for patient data')
print(X_train_pt.shape, X_val_pt.shape, X_test_pt.shape)
# Out:
# AE Embeddings for patient data
# (341, 128) (126, 128) (184, 128)

# %% [markdown]
# ## Load and preprocess PFS data

# %%
for ind in [1]:
    data_filename = os.path.join(data_dir,'cleaned_mm%d_2mos_pfs_ind.pkl'%(ind))
    train, test, valid = MMRF_utils.get_train_test_valid(data_filename, ind, show_features=False)

    print('\nPreprocess patient data in MMRF')
    train_df = MMRF_utils.preprocess_patient_data(train, num_clin_visits=1)  
    print('Train', train_df.shape)

    valid_df = MMRF_utils.preprocess_patient_data(valid, num_clin_visits=1)  
    print('Val', valid_df.shape)

    test_df = MMRF_utils.preprocess_patient_data(test, num_clin_visits=1)  
    print('Test', test_df.shape)
# Out:
# loading from: /Users/eshikasaxena/Documents/MLHC/mm-cell_lines/data/cleaned_mm1_2mos_pfs_ind.pkl
#
# Preprocess patient data in MMRF
# Keep first 1 clinical visits.
# Train (461, 43)
# Keep first 1 clinical visits.
# Val (161, 43)
# Keep first 1 clinical visits.
# Test (214, 43)

# %%
train_pfs = train_df[['pids','pfs']]
train_pfs = train_pfs.set_index('pids')

val_pfs = valid_df[['pids','pfs']]
val_pfs = val_pfs.set_index('pids')

test_pfs = test_df[['pids','pfs']]
test_pfs = test_pfs.set_index('pids')

# %% [markdown]
# ## Preprocess and format patient data for model training

# %%
train_index_pt = list(set(X_train_pt.index).intersection(train_pfs.index))
val_index_pt = list(set(X_val_pt.index).intersection(val_pfs.index))
test_index_pt = list(set(X_test_pt.index).intersection(test_pfs.index))

# %%
X_train_pt = X_train_pt.loc[train_index_pt]
X_val_pt = X_val_pt.loc[val_index_pt]
X_test_pt = X_test_pt.loc[test_index_pt]

# %%
Y_train_pfs = train_pfs.loc[train_index_pt]
Y_val_pfs = val_pfs.loc[val_index_pt]
Y_test_pfs = test_pfs.loc[test_index_pt]

# binary outcome used for classifier; greater than 12 = 1, less than or equal to 12 = 0
bY_train_pfs = (Y_train_pfs >12).astype(int)
bY_val_pfs = (Y_val_pfs >12).astype(int)
bY_test_pfs = (Y_test_pfs >12).astype(int)

# onehot encode binary outcomes
bY_train_pfs_oneHot = K.utils.to_categorical(bY_train_pfs, 2)
bY_val_pfs_oneHot = K.utils.to_categorical(bY_val_pfs, 2)
bY_test_pfs_oneHot = K.utils.to_categorical(bY_test_pfs, 2)

# %%
print('MMRF RNA-seq and PFS Data')
print('Train', X_train_pt.shape, bY_train_pfs_oneHot.shape)
print('Val', X_val_pt.shape, bY_val_pfs_oneHot.shape)
print('Test', X_test_pt.shape, bY_test_pfs_oneHot.shape)
# Out:
# MMRF RNA-seq and PFS Data
# Train (313, 128) (313, 2)
# Val (97, 128) (97, 2)
# Test (142, 128) (142, 2)

# %% [markdown]
# ## EDA: Plotting cell viability score distributions

# %%
fig, ax = plt.subplots(4, 4, figsize = (15,12))

ax_new = Y_train.hist(bins=10, ax=ax.ravel()[:13])
for i in range(13):
    ax_new[i].set_xlabel("Cell Viability")
    ax_new[i].set_ylabel("Cell Lines") 
    ax_new[i].set_title(f"Distribution for {Y_train.columns[i].split(' ')[0]}")
    ax_new[i].set_xlim(-1*4,4)
    ax_new[i].grid(False)

plt.tight_layout()

# %% [markdown]
# ## Define classifier architecture

# %%
def generate_classifier(N_in):
    inputs = K.layers.Input(shape = (N_in,))
    x = K.layers.Dense(64, activation='relu', kernel_regularizer=K.regularizers.l2(l=0.01))(inputs)
    x = K.layers.Dense(32, activation='relu', kernel_regularizer=K.regularizers.l2(l=0.01))(x)   
    y1 = K.layers.Dense(2, activation='softmax', kernel_regularizer=K.regularizers.l2(l=0.01), name='y1')(x)
    y2 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y2')(x)
    y3 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y3')(x)
    y4 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y4')(x)
    y5 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y5')(x)
    y6 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y6')(x)
    y7 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y7')(x)
    y8 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y8')(x)
    y9 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y9')(x)
    y10 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y10')(x)
    y11 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y11')(x)
    y12 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y12')(x)
    y13 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y13')(x)
    
    combined = [y1,y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13]
    tensors = [tf.expand_dims(i, axis=1) for i in combined]
    output = K.layers.concatenate(tensors, axis=1)
    
    model = K.models.Model(inputs = inputs, outputs = output)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
def plot_loss(perf_dict):
    fig = plt.figure(figsize=(15,10))
    ax1 = plt.subplot(2,2,1)
    ax2 = plt.subplot(2,2,2)
    loss = perf_dict['loss']
    val_loss = perf_dict['val_loss']
    ax1.plot(loss)
    ax2.plot(val_loss)
    ax1.set_xlabel('epochs')
    ax2.set_xlabel('epochs')

    ax1.set_ylabel('loss')
    ax2.set_ylabel('val_loss')
    plt.show()

# %% [markdown]
# ## Train Classifier Model
#
# * Predicts a binarized cell viability score for 13 different genes that were perturbed using CCLE embeddings from autoencoder trained on MMRF data

# %%
classifier = generate_classifier(X_train.shape[1])

print("Input", classifier.input_shape)
print("Output", classifier.output_shape)
classifier.summary()
# Out:
# Input (None, 128)
# Output (None, 13, 2)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           2080        dense[0][0]
# __________________________________________________________________________________________________
# y1 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y2 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y3 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y4 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y5 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y6 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y7 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y8 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y9 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y10 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y11 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y12 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y13 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 1, 2)         0           y1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 1, 2)         0           y2[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_2 (TFOpLambda)   (None, 1, 2)         0           y3[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_3 (TFOpLambda)   (None, 1, 2)         0           y4[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_4 (TFOpLambda)   (None, 1, 2)         0           y5[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_5 (TFOpLambda)   (None, 1, 2)         0           y6[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_6 (TFOpLambda)   (None, 1, 2)         0           y7[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_7 (TFOpLambda)   (None, 1, 2)         0           y8[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_8 (TFOpLambda)   (None, 1, 2)         0           y9[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_9 (TFOpLambda)   (None, 1, 2)         0           y10[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_10 (TFOpLambda)  (None, 1, 2)         0           y11[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_11 (TFOpLambda)  (None, 1, 2)         0           y12[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_12 (TFOpLambda)  (None, 1, 2)         0           y13[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 13, 2)        0           tf.expand_dims[0][0]
#                                                                  tf.expand_dims_1[0][0]
#                                                                  tf.expand_dims_2[0][0]
#                                                                  tf.expand_dims_3[0][0]
#                                                                  tf.expand_dims_4[0][0]
#                                                                  tf.expand_dims_5[0][0]
#                                                                  tf.expand_dims_6[0][0]
#                                                                  tf.expand_dims_7[0][0]
#                                                                  tf.expand_dims_8[0][0]
#                                                                  tf.expand_dims_9[0][0]
#                                                                  tf.expand_dims_10[0][0]
#                                                                  tf.expand_dims_11[0][0]
#                                                                  tf.expand_dims_12[0][0]
# ==================================================================================================
# Total params: 11,194
# Trainable params: 11,194
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
classifier_history = classifier.fit(X_train,bY_train_oneHot,epochs=100, validation_data=(X_val, bY_val_oneHot),verbose=0)

# %%
plot_loss(classifier_history.history)

# %%
y_train_classifierPred = np.array(classifier.predict(X_train))[:,:,1]
y_test_classifierPred = np.array(classifier.predict(X_test))[:,:,1]

bY_test_true = bY_test_oneHot[:,:,1]
bY_train_true = bY_train_oneHot[:,:,1]

print(y_train_classifierPred.shape, y_test_classifierPred.shape)
print(bY_train_true.shape, bY_test_true.shape)
# Out:
# (559, 13) (165, 13)
# (559, 13) (165, 13)

# %%
n_classes = 13
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(bY_test_true[:, i], y_test_classifierPred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(bY_test_true.ravel(), y_test_classifierPred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
# Out:
# /Users/eshikasaxena/miniconda3/envs/cs109b/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
# /Users/eshikasaxena/miniconda3/envs/cs109b/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
# /Users/eshikasaxena/miniconda3/envs/cs109b/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
# /Users/eshikasaxena/miniconda3/envs/cs109b/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
# /Users/eshikasaxena/miniconda3/envs/cs109b/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

plt.plot([0, 1], [0, 1], 'k--', lw=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Average ROC Curves')
plt.legend(loc="lower right")
plt.show()

# %%
fig, axes = plt.subplots(5, 3, figsize=(15,15))
lw = 2

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, ax, color in zip(range(13), axes.ravel(), colors):
    ax.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
    ax.plot([0, 1], [0, 1], 'k--', lw=lw)
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(f'ROC Curve for Class {i}')
    ax.legend(loc="lower right")

plt.tight_layout()

# %% [markdown]
# ## Fine-tuning on patient data
# * Freeze network except the last layer
# * Fine-tune on MMRF patient RNA-seq embeddings from the same autoencoder to predict binarized progression free survival (PFS > 12 or not)

# %%
classifier.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           2080        dense[0][0]
# __________________________________________________________________________________________________
# y1 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y2 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y3 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y4 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y5 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y6 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y7 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y8 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y9 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y10 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y11 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y12 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y13 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 1, 2)         0           y1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 1, 2)         0           y2[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_2 (TFOpLambda)   (None, 1, 2)         0           y3[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_3 (TFOpLambda)   (None, 1, 2)         0           y4[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_4 (TFOpLambda)   (None, 1, 2)         0           y5[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_5 (TFOpLambda)   (None, 1, 2)         0           y6[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_6 (TFOpLambda)   (None, 1, 2)         0           y7[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_7 (TFOpLambda)   (None, 1, 2)         0           y8[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_8 (TFOpLambda)   (None, 1, 2)         0           y9[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_9 (TFOpLambda)   (None, 1, 2)         0           y10[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_10 (TFOpLambda)  (None, 1, 2)         0           y11[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_11 (TFOpLambda)  (None, 1, 2)         0           y12[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_12 (TFOpLambda)  (None, 1, 2)         0           y13[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 13, 2)        0           tf.expand_dims[0][0]
#                                                                  tf.expand_dims_1[0][0]
#                                                                  tf.expand_dims_2[0][0]
#                                                                  tf.expand_dims_3[0][0]
#                                                                  tf.expand_dims_4[0][0]
#                                                                  tf.expand_dims_5[0][0]
#                                                                  tf.expand_dims_6[0][0]
#                                                                  tf.expand_dims_7[0][0]
#                                                                  tf.expand_dims_8[0][0]
#                                                                  tf.expand_dims_9[0][0]
#                                                                  tf.expand_dims_10[0][0]
#                                                                  tf.expand_dims_11[0][0]
#                                                                  tf.expand_dims_12[0][0]
# ==================================================================================================
# Total params: 11,194
# Trainable params: 11,194
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# freeze layers
classifier.layers[0].trainable = False
classifier.layers[1].trainable = False
classifier.layers[2].trainable = False

transfer = classifier.layers[2].output

final_output = K.layers.Dense(2, activation='softmax', kernel_regularizer=K.regularizers.l2(l=0.01), name='final')(transfer)

transfer_model = K.models.Model(inputs=classifier.input, outputs=final_output)

transfer_model.compile(optimizer='adam',
                  loss='categorical_crossentropy', metrics=['accuracy'])

print(transfer_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128)]             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# final (Dense)                (None, 2)                 66
# =================================================================
# Total params: 10,402
# Trainable params: 66
# Non-trainable params: 10,336
# _________________________________________________________________
# None

# %%
history_pt = transfer_model.fit(X_train_pt, bY_train_pfs_oneHot, epochs=100, validation_data=(X_val_pt, bY_val_pfs_oneHot))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 26ms/step - loss: 1.4016 - accuracy: 0.6400 - val_loss: 1.0896 - val_accuracy: 0.6186
# Epoch 2/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.2889 - accuracy: 0.6098 - val_loss: 1.0511 - val_accuracy: 0.6082
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.1559 - accuracy: 0.6250 - val_loss: 1.0184 - val_accuracy: 0.5979
# Epoch 4/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2032 - accuracy: 0.6006 - val_loss: 0.9891 - val_accuracy: 0.5567
# Epoch 5/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0390 - accuracy: 0.6134 - val_loss: 0.9651 - val_accuracy: 0.5464
# Epoch 6/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0709 - accuracy: 0.5751 - val_loss: 0.9429 - val_accuracy: 0.5464
# Epoch 7/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0015 - accuracy: 0.5776 - val_loss: 0.9229 - val_accuracy: 0.5155
# Epoch 8/100
# 10/10 [==============================] - 0s 14ms/step - loss: 1.0717 - accuracy: 0.5857 - val_loss: 0.9056 - val_accuracy: 0.5155
# Epoch 9/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9728 - accuracy: 0.6022 - val_loss: 0.8906 - val_accuracy: 0.5258
# Epoch 10/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9308 - accuracy: 0.5527 - val_loss: 0.8772 - val_accuracy: 0.5361
# Epoch 11/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0101 - accuracy: 0.5343 - val_loss: 0.8633 - val_accuracy: 0.5361
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9463 - accuracy: 0.5357 - val_loss: 0.8509 - val_accuracy: 0.5464
# Epoch 13/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8900 - accuracy: 0.5632 - val_loss: 0.8398 - val_accuracy: 0.5361
# Epoch 14/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8512 - accuracy: 0.5651 - val_loss: 0.8288 - val_accuracy: 0.5361
# Epoch 15/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8645 - accuracy: 0.5415 - val_loss: 0.8189 - val_accuracy: 0.5361
# Epoch 16/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8563 - accuracy: 0.5549 - val_loss: 0.8092 - val_accuracy: 0.5361
# Epoch 17/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8395 - accuracy: 0.5587 - val_loss: 0.8007 - val_accuracy: 0.5464
# Epoch 18/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8499 - accuracy: 0.5481 - val_loss: 0.7919 - val_accuracy: 0.5464
# Epoch 19/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8389 - accuracy: 0.5565 - val_loss: 0.7836 - val_accuracy: 0.5464
# Epoch 20/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8229 - accuracy: 0.5740 - val_loss: 0.7761 - val_accuracy: 0.5567
# Epoch 21/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8177 - accuracy: 0.5347 - val_loss: 0.7693 - val_accuracy: 0.5670
# Epoch 22/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8198 - accuracy: 0.5376 - val_loss: 0.7635 - val_accuracy: 0.5670
# Epoch 23/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7823 - accuracy: 0.5457 - val_loss: 0.7575 - val_accuracy: 0.5979
# Epoch 24/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8035 - accuracy: 0.5487 - val_loss: 0.7525 - val_accuracy: 0.5979
# Epoch 25/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7700 - accuracy: 0.5978 - val_loss: 0.7478 - val_accuracy: 0.6289
# Epoch 26/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7587 - accuracy: 0.5670 - val_loss: 0.7431 - val_accuracy: 0.6495
# Epoch 27/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7661 - accuracy: 0.5952 - val_loss: 0.7392 - val_accuracy: 0.6598
# Epoch 28/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.7676 - accuracy: 0.5900 - val_loss: 0.7355 - val_accuracy: 0.6598
# Epoch 29/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.7601 - accuracy: 0.5901 - val_loss: 0.7322 - val_accuracy: 0.6701
# Epoch 30/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.7651 - accuracy: 0.5903 - val_loss: 0.7295 - val_accuracy: 0.6701
# Epoch 31/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.7430 - accuracy: 0.6423 - val_loss: 0.7270 - val_accuracy: 0.6289
# Epoch 32/100
# 10/10 [==============================] - 0s 17ms/step - loss: 0.7359 - accuracy: 0.6416 - val_loss: 0.7247 - val_accuracy: 0.6392
# Epoch 33/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7284 - accuracy: 0.6331 - val_loss: 0.7226 - val_accuracy: 0.6289
# Epoch 34/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.7391 - accuracy: 0.6396 - val_loss: 0.7209 - val_accuracy: 0.6392
# Epoch 35/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7214 - accuracy: 0.6505 - val_loss: 0.7192 - val_accuracy: 0.6289
# Epoch 36/100
# 10/10 [==============================] - 0s 17ms/step - loss: 0.7253 - accuracy: 0.6486 - val_loss: 0.7181 - val_accuracy: 0.6289
# Epoch 37/100
# 10/10 [==============================] - 0s 18ms/step - loss: 0.7122 - accuracy: 0.6664 - val_loss: 0.7171 - val_accuracy: 0.6289
# Epoch 38/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.7298 - accuracy: 0.6324 - val_loss: 0.7158 - val_accuracy: 0.6289
# Epoch 39/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7036 - accuracy: 0.6656 - val_loss: 0.7146 - val_accuracy: 0.6289
# Epoch 40/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7338 - accuracy: 0.6436 - val_loss: 0.7137 - val_accuracy: 0.6392
# Epoch 41/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7207 - accuracy: 0.6230 - val_loss: 0.7128 - val_accuracy: 0.6495
# Epoch 42/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7074 - accuracy: 0.6544 - val_loss: 0.7120 - val_accuracy: 0.6495
# Epoch 43/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7088 - accuracy: 0.6497 - val_loss: 0.7115 - val_accuracy: 0.6495
# Epoch 44/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7219 - accuracy: 0.6320 - val_loss: 0.7109 - val_accuracy: 0.6392
# Epoch 45/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6978 - accuracy: 0.6579 - val_loss: 0.7103 - val_accuracy: 0.6289
# Epoch 46/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6936 - accuracy: 0.6834 - val_loss: 0.7097 - val_accuracy: 0.6392
# Epoch 47/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7327 - accuracy: 0.6146 - val_loss: 0.7093 - val_accuracy: 0.6289
# Epoch 48/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6858 - accuracy: 0.6782 - val_loss: 0.7090 - val_accuracy: 0.6186
# Epoch 49/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6971 - accuracy: 0.6449 - val_loss: 0.7086 - val_accuracy: 0.6186
# Epoch 50/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7071 - accuracy: 0.6244 - val_loss: 0.7083 - val_accuracy: 0.6186
# Epoch 51/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6853 - accuracy: 0.6572 - val_loss: 0.7079 - val_accuracy: 0.6186
# Epoch 52/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6770 - accuracy: 0.6805 - val_loss: 0.7077 - val_accuracy: 0.6289
# Epoch 53/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6965 - accuracy: 0.6610 - val_loss: 0.7076 - val_accuracy: 0.6289
# Epoch 54/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6840 - accuracy: 0.6696 - val_loss: 0.7073 - val_accuracy: 0.6289
# Epoch 55/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6880 - accuracy: 0.6646 - val_loss: 0.7071 - val_accuracy: 0.6289
# Epoch 56/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6672 - accuracy: 0.6881 - val_loss: 0.7068 - val_accuracy: 0.6289
# Epoch 57/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6907 - accuracy: 0.6396 - val_loss: 0.7068 - val_accuracy: 0.6289
# Epoch 58/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6867 - accuracy: 0.6731 - val_loss: 0.7065 - val_accuracy: 0.6289
# Epoch 59/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.6774 - accuracy: 0.6779 - val_loss: 0.7064 - val_accuracy: 0.6289
# Epoch 60/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6636 - accuracy: 0.6959 - val_loss: 0.7063 - val_accuracy: 0.6289
# Epoch 61/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7004 - accuracy: 0.6451 - val_loss: 0.7062 - val_accuracy: 0.6289
# Epoch 62/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6877 - accuracy: 0.6711 - val_loss: 0.7060 - val_accuracy: 0.6289
# Epoch 63/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6615 - accuracy: 0.6936 - val_loss: 0.7059 - val_accuracy: 0.6289
# Epoch 64/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6772 - accuracy: 0.6650 - val_loss: 0.7058 - val_accuracy: 0.6289
# Epoch 65/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6907 - accuracy: 0.6752 - val_loss: 0.7056 - val_accuracy: 0.6289
# Epoch 66/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6855 - accuracy: 0.6769 - val_loss: 0.7055 - val_accuracy: 0.6289
# Epoch 67/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6780 - accuracy: 0.6759 - val_loss: 0.7056 - val_accuracy: 0.6289
# Epoch 68/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6737 - accuracy: 0.6592 - val_loss: 0.7054 - val_accuracy: 0.6289
# Epoch 69/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7030 - accuracy: 0.6323 - val_loss: 0.7053 - val_accuracy: 0.6289
# Epoch 70/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6555 - accuracy: 0.6971 - val_loss: 0.7053 - val_accuracy: 0.6289
# Epoch 71/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6704 - accuracy: 0.6723 - val_loss: 0.7053 - val_accuracy: 0.6289
# Epoch 72/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6922 - accuracy: 0.6483 - val_loss: 0.7051 - val_accuracy: 0.6289
# Epoch 73/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6788 - accuracy: 0.6722 - val_loss: 0.7051 - val_accuracy: 0.6289
# Epoch 74/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6673 - accuracy: 0.6927 - val_loss: 0.7050 - val_accuracy: 0.6289
# Epoch 75/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6623 - accuracy: 0.6953 - val_loss: 0.7050 - val_accuracy: 0.6289
# Epoch 76/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6749 - accuracy: 0.6746 - val_loss: 0.7050 - val_accuracy: 0.6289
# Epoch 77/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7021 - accuracy: 0.6716 - val_loss: 0.7049 - val_accuracy: 0.6289
# Epoch 78/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6496 - accuracy: 0.7056 - val_loss: 0.7049 - val_accuracy: 0.6289
# Epoch 79/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6627 - accuracy: 0.7058 - val_loss: 0.7047 - val_accuracy: 0.6289
# Epoch 80/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6598 - accuracy: 0.7065 - val_loss: 0.7048 - val_accuracy: 0.6289
# Epoch 81/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6751 - accuracy: 0.6745 - val_loss: 0.7047 - val_accuracy: 0.6289
# Epoch 82/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6572 - accuracy: 0.7070 - val_loss: 0.7046 - val_accuracy: 0.6289
# Epoch 83/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6778 - accuracy: 0.6984 - val_loss: 0.7047 - val_accuracy: 0.6289
# Epoch 84/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6667 - accuracy: 0.6882 - val_loss: 0.7045 - val_accuracy: 0.6289
# Epoch 85/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6865 - accuracy: 0.6486 - val_loss: 0.7046 - val_accuracy: 0.6289
# Epoch 86/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6602 - accuracy: 0.6960 - val_loss: 0.7050 - val_accuracy: 0.6289
# Epoch 87/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6818 - accuracy: 0.6673 - val_loss: 0.7045 - val_accuracy: 0.6289
# Epoch 88/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.6603 - accuracy: 0.7160 - val_loss: 0.7048 - val_accuracy: 0.6289
# Epoch 89/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6769 - accuracy: 0.6955 - val_loss: 0.7046 - val_accuracy: 0.6289
# Epoch 90/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6839 - accuracy: 0.6761 - val_loss: 0.7045 - val_accuracy: 0.6289
# Epoch 91/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6617 - accuracy: 0.6803 - val_loss: 0.7045 - val_accuracy: 0.6289
# Epoch 92/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6621 - accuracy: 0.6971 - val_loss: 0.7044 - val_accuracy: 0.6289
# Epoch 93/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6754 - accuracy: 0.6948 - val_loss: 0.7043 - val_accuracy: 0.6289
# Epoch 94/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6705 - accuracy: 0.6978 - val_loss: 0.7044 - val_accuracy: 0.6289
# Epoch 95/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6940 - accuracy: 0.6665 - val_loss: 0.7045 - val_accuracy: 0.6289
# Epoch 96/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6559 - accuracy: 0.7172 - val_loss: 0.7044 - val_accuracy: 0.6289
# Epoch 97/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6659 - accuracy: 0.6845 - val_loss: 0.7043 - val_accuracy: 0.6289
# Epoch 98/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6824 - accuracy: 0.6764 - val_loss: 0.7041 - val_accuracy: 0.6289
# Epoch 99/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6684 - accuracy: 0.6905 - val_loss: 0.7042 - val_accuracy: 0.6289
# Epoch 100/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6623 - accuracy: 0.6865 - val_loss: 0.7043 - val_accuracy: 0.6289

# %%
plot_loss(history_pt.history)

# %%
y_train_transferPred_probs = np.array(transfer_model.predict(X_train_pt))[:,1]
y_test_transferPred_probs = np.array(transfer_model.predict(X_test_pt))[:,1]

y_train_transferPred = np.where(y_train_transferPred_probs > 0.5, 1, 0)
y_test_transferPred = np.where(y_test_transferPred_probs > 0.5, 1, 0)

bY_train_true_pfs = bY_train_pfs_oneHot[:,1]
bY_test_true_pfs = bY_test_pfs_oneHot[:,1]

print(y_train_transferPred.shape, y_test_transferPred.shape)
print(bY_train_true_pfs.shape, bY_test_true_pfs.shape)
# Out:
# (313,) (142,)
# (313,) (142,)

# %% [markdown]
# ## Baseline Model
# * Same architecture (2 dense layers and a head) but only trained on the patient RNA-seq embeddings, not cell line data, for binarized PFS prediction

# %%
inputs = K.layers.Input(shape = (128,))
x = K.layers.Dense(64, activation='relu', kernel_regularizer=K.regularizers.l2(l=0.01))(inputs)
x = K.layers.Dense(32, activation='relu', kernel_regularizer=K.regularizers.l2(l=0.01))(x)

output = K.layers.Dense(2, activation='softmax', kernel_regularizer=K.regularizers.l2(l=0.01), name='final')(x)

baseline_model = K.models.Model(inputs=inputs, outputs=output)

baseline_model.compile(optimizer='adam',
                  loss='categorical_crossentropy', metrics=['accuracy'])

print(baseline_model.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128)]             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# final (Dense)                (None, 2)                 66
# =================================================================
# Total params: 10,402
# Trainable params: 10,402
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history_baseline = baseline_model.fit(X_train_pt, bY_train_pfs_oneHot, epochs=100, validation_data=(X_val_pt, bY_val_pfs_oneHot))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 32ms/step - loss: 3.6593 - accuracy: 0.5628 - val_loss: 2.6792 - val_accuracy: 0.5258
# Epoch 2/100
# 10/10 [==============================] - 0s 11ms/step - loss: 2.3150 - accuracy: 0.6552 - val_loss: 2.5299 - val_accuracy: 0.6289
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.8872 - accuracy: 0.7700 - val_loss: 2.2658 - val_accuracy: 0.5979
# Epoch 4/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.7654 - accuracy: 0.7887 - val_loss: 2.2583 - val_accuracy: 0.5670
# Epoch 5/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.7309 - accuracy: 0.8078 - val_loss: 2.1730 - val_accuracy: 0.6082
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.5719 - accuracy: 0.8505 - val_loss: 2.1767 - val_accuracy: 0.5979
# Epoch 7/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.5734 - accuracy: 0.8550 - val_loss: 2.1996 - val_accuracy: 0.5876
# Epoch 8/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.5268 - accuracy: 0.9074 - val_loss: 2.1225 - val_accuracy: 0.6289
# Epoch 9/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.4855 - accuracy: 0.8843 - val_loss: 2.1304 - val_accuracy: 0.5876
# Epoch 10/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.4533 - accuracy: 0.9062 - val_loss: 2.1187 - val_accuracy: 0.6289
# Epoch 11/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.4079 - accuracy: 0.9077 - val_loss: 2.1138 - val_accuracy: 0.5876
# Epoch 12/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.4412 - accuracy: 0.8807 - val_loss: 2.0995 - val_accuracy: 0.6186
# Epoch 13/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3955 - accuracy: 0.9230 - val_loss: 2.0946 - val_accuracy: 0.5979
# Epoch 14/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3586 - accuracy: 0.9589 - val_loss: 2.0813 - val_accuracy: 0.6082
# Epoch 15/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3430 - accuracy: 0.9440 - val_loss: 2.0653 - val_accuracy: 0.6082
# Epoch 16/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.3167 - accuracy: 0.9522 - val_loss: 2.0689 - val_accuracy: 0.6082
# Epoch 17/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.2852 - accuracy: 0.9542 - val_loss: 2.0465 - val_accuracy: 0.6186
# Epoch 18/100
# 10/10 [==============================] - 0s 12ms/step - loss: 1.2799 - accuracy: 0.9613 - val_loss: 2.0412 - val_accuracy: 0.6186
# Epoch 19/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.2575 - accuracy: 0.9719 - val_loss: 2.0605 - val_accuracy: 0.6082
# Epoch 20/100
# 10/10 [==============================] - 0s 12ms/step - loss: 1.2489 - accuracy: 0.9530 - val_loss: 2.0457 - val_accuracy: 0.5773
# Epoch 21/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2355 - accuracy: 0.9684 - val_loss: 2.0359 - val_accuracy: 0.6082
# Epoch 22/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2327 - accuracy: 0.9587 - val_loss: 2.0243 - val_accuracy: 0.5979
# Epoch 23/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.1786 - accuracy: 0.9663 - val_loss: 2.0220 - val_accuracy: 0.5567
# Epoch 24/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.1635 - accuracy: 0.9736 - val_loss: 2.0235 - val_accuracy: 0.6186
# Epoch 25/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.1417 - accuracy: 0.9689 - val_loss: 1.9973 - val_accuracy: 0.5670
# Epoch 26/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.1330 - accuracy: 0.9819 - val_loss: 2.0034 - val_accuracy: 0.5876
# Epoch 27/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.1194 - accuracy: 0.9847 - val_loss: 2.0071 - val_accuracy: 0.5979
# Epoch 28/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1003 - accuracy: 0.9768 - val_loss: 1.9815 - val_accuracy: 0.5876
# Epoch 29/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0929 - accuracy: 0.9813 - val_loss: 1.9840 - val_accuracy: 0.6082
# Epoch 30/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0589 - accuracy: 0.9855 - val_loss: 1.9688 - val_accuracy: 0.5876
# Epoch 31/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0596 - accuracy: 0.9823 - val_loss: 1.9700 - val_accuracy: 0.5979
# Epoch 32/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0386 - accuracy: 0.9767 - val_loss: 1.9615 - val_accuracy: 0.5773
# Epoch 33/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0391 - accuracy: 0.9808 - val_loss: 1.9522 - val_accuracy: 0.6082
# Epoch 34/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0061 - accuracy: 0.9901 - val_loss: 1.9531 - val_accuracy: 0.5567
# Epoch 35/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0007 - accuracy: 0.9946 - val_loss: 1.9629 - val_accuracy: 0.6186
# Epoch 36/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9878 - accuracy: 0.9965 - val_loss: 1.9609 - val_accuracy: 0.6082
# Epoch 37/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9812 - accuracy: 0.9822 - val_loss: 1.9637 - val_accuracy: 0.6082
# Epoch 38/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9721 - accuracy: 0.9772 - val_loss: 1.9646 - val_accuracy: 0.5876
# Epoch 39/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9569 - accuracy: 0.9867 - val_loss: 1.9500 - val_accuracy: 0.5979
# Epoch 40/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9359 - accuracy: 0.9894 - val_loss: 1.9484 - val_accuracy: 0.6082
# Epoch 41/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9230 - accuracy: 0.9983 - val_loss: 1.9280 - val_accuracy: 0.6082
# Epoch 42/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9088 - accuracy: 0.9910 - val_loss: 1.9244 - val_accuracy: 0.5670
# Epoch 43/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9006 - accuracy: 0.9867 - val_loss: 1.9277 - val_accuracy: 0.6082
# Epoch 44/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8911 - accuracy: 0.9994 - val_loss: 1.9373 - val_accuracy: 0.6186
# Epoch 45/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8788 - accuracy: 0.9899 - val_loss: 1.9033 - val_accuracy: 0.5670
# Epoch 46/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8699 - accuracy: 0.9904 - val_loss: 1.9242 - val_accuracy: 0.6082
# Epoch 47/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8596 - accuracy: 1.0000 - val_loss: 1.9137 - val_accuracy: 0.5876
# Epoch 48/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8488 - accuracy: 0.9865 - val_loss: 1.8977 - val_accuracy: 0.5567
# Epoch 49/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8391 - accuracy: 0.9983 - val_loss: 1.9102 - val_accuracy: 0.5670
# Epoch 50/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8332 - accuracy: 0.9983 - val_loss: 1.9523 - val_accuracy: 0.6082
# Epoch 51/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8172 - accuracy: 0.9967 - val_loss: 1.9216 - val_accuracy: 0.5979
# Epoch 52/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8043 - accuracy: 0.9923 - val_loss: 1.8943 - val_accuracy: 0.5464
# Epoch 53/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8103 - accuracy: 0.9940 - val_loss: 1.9386 - val_accuracy: 0.5979
# Epoch 54/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7878 - accuracy: 0.9876 - val_loss: 1.8810 - val_accuracy: 0.5773
# Epoch 55/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7869 - accuracy: 0.9956 - val_loss: 1.8922 - val_accuracy: 0.6082
# Epoch 56/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7618 - accuracy: 0.9987 - val_loss: 1.8609 - val_accuracy: 0.5670
# Epoch 57/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7541 - accuracy: 1.0000 - val_loss: 1.9153 - val_accuracy: 0.5876
# Epoch 58/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7506 - accuracy: 1.0000 - val_loss: 1.8941 - val_accuracy: 0.6082
# Epoch 59/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7382 - accuracy: 0.9905 - val_loss: 1.8715 - val_accuracy: 0.5670
# Epoch 60/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7315 - accuracy: 0.9939 - val_loss: 1.8349 - val_accuracy: 0.5773
# Epoch 61/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7261 - accuracy: 0.9949 - val_loss: 1.9173 - val_accuracy: 0.5979
# Epoch 62/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7123 - accuracy: 0.9953 - val_loss: 1.9089 - val_accuracy: 0.6186
# Epoch 63/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7078 - accuracy: 0.9886 - val_loss: 1.8379 - val_accuracy: 0.5567
# Epoch 64/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.7093 - accuracy: 0.9987 - val_loss: 1.8601 - val_accuracy: 0.5979
# Epoch 65/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6853 - accuracy: 1.0000 - val_loss: 1.8983 - val_accuracy: 0.5876
# Epoch 66/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6812 - accuracy: 0.9949 - val_loss: 1.8348 - val_accuracy: 0.5670
# Epoch 67/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6684 - accuracy: 0.9987 - val_loss: 1.8386 - val_accuracy: 0.5773
# Epoch 68/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6630 - accuracy: 1.0000 - val_loss: 1.9105 - val_accuracy: 0.5979
# Epoch 69/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6616 - accuracy: 0.9983 - val_loss: 1.8232 - val_accuracy: 0.5773
# Epoch 70/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6505 - accuracy: 0.9966 - val_loss: 1.8341 - val_accuracy: 0.5258
# Epoch 71/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6475 - accuracy: 0.9924 - val_loss: 1.8059 - val_accuracy: 0.5670
# Epoch 72/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6351 - accuracy: 0.9942 - val_loss: 1.8768 - val_accuracy: 0.5979
# Epoch 73/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6237 - accuracy: 1.0000 - val_loss: 1.8240 - val_accuracy: 0.5258
# Epoch 74/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6159 - accuracy: 0.9987 - val_loss: 1.7865 - val_accuracy: 0.5567
# Epoch 75/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6120 - accuracy: 0.9987 - val_loss: 1.7889 - val_accuracy: 0.5567
# Epoch 76/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5987 - accuracy: 1.0000 - val_loss: 1.8545 - val_accuracy: 0.6082
# Epoch 77/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5966 - accuracy: 0.9979 - val_loss: 1.8090 - val_accuracy: 0.5464
# Epoch 78/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5913 - accuracy: 1.0000 - val_loss: 1.7973 - val_accuracy: 0.5464
# Epoch 79/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5824 - accuracy: 1.0000 - val_loss: 1.7854 - val_accuracy: 0.5670
# Epoch 80/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5760 - accuracy: 1.0000 - val_loss: 1.8015 - val_accuracy: 0.5876
# Epoch 81/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5651 - accuracy: 1.0000 - val_loss: 1.7635 - val_accuracy: 0.5567
# Epoch 82/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5598 - accuracy: 1.0000 - val_loss: 1.7747 - val_accuracy: 0.5670
# Epoch 83/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5533 - accuracy: 1.0000 - val_loss: 1.8343 - val_accuracy: 0.5979
# Epoch 84/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5522 - accuracy: 1.0000 - val_loss: 1.7574 - val_accuracy: 0.5464
# Epoch 85/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5412 - accuracy: 1.0000 - val_loss: 1.8114 - val_accuracy: 0.5567
# Epoch 86/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5352 - accuracy: 0.9979 - val_loss: 1.7667 - val_accuracy: 0.5361
# Epoch 87/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5369 - accuracy: 0.9991 - val_loss: 1.8259 - val_accuracy: 0.5876
# Epoch 88/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5240 - accuracy: 1.0000 - val_loss: 1.7438 - val_accuracy: 0.5670
# Epoch 89/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5190 - accuracy: 1.0000 - val_loss: 1.7680 - val_accuracy: 0.5773
# Epoch 90/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5119 - accuracy: 1.0000 - val_loss: 1.7375 - val_accuracy: 0.5567
# Epoch 91/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5046 - accuracy: 0.9978 - val_loss: 1.7821 - val_accuracy: 0.5155
# Epoch 92/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5202 - accuracy: 0.9872 - val_loss: 1.6842 - val_accuracy: 0.5361
# Epoch 93/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5214 - accuracy: 0.9933 - val_loss: 1.7882 - val_accuracy: 0.5773
# Epoch 94/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5046 - accuracy: 0.9942 - val_loss: 1.7950 - val_accuracy: 0.5670
# Epoch 95/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4995 - accuracy: 1.0000 - val_loss: 1.7913 - val_accuracy: 0.5979
# Epoch 96/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4907 - accuracy: 1.0000 - val_loss: 1.7557 - val_accuracy: 0.5979
# Epoch 97/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4829 - accuracy: 1.0000 - val_loss: 1.7495 - val_accuracy: 0.5258
# Epoch 98/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4788 - accuracy: 0.9914 - val_loss: 1.7511 - val_accuracy: 0.5567
# Epoch 99/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4680 - accuracy: 1.0000 - val_loss: 1.7852 - val_accuracy: 0.5670
# Epoch 100/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4564 - accuracy: 1.0000 - val_loss: 1.7460 - val_accuracy: 0.5670

# %%
plot_loss(history_baseline.history)

# %%
y_train_baselinePred_probs = np.array(baseline_model.predict(X_train_pt))[:,1]
y_test_baselinePred_probs = np.array(baseline_model.predict(X_test_pt))[:,1]

y_train_baselinePred = np.where(y_train_baselinePred_probs > 0.5, 1, 0)
y_test_baselinePred = np.where(y_test_baselinePred_probs > 0.5, 1, 0)

bY_train_true_pfs = bY_train_pfs_oneHot[:,1]
bY_test_true_pfs = bY_test_pfs_oneHot[:,1]

print(y_train_transferPred.shape, y_test_transferPred.shape)
print(bY_train_true_pfs.shape, bY_test_true_pfs.shape)
# Out:
# (313,) (142,)
# (313,) (142,)

# %% [markdown]
# ## Calculate and display metrics

# %%
def get_stats(true_pfs,pred_pfs):
    metrics = [accuracy_score, precision_score, recall_score, f1_score]
    return([np.round(metric(true_pfs, pred_pfs),2) for metric in metrics])

# %%
val_stats_baseline = get_stats(bY_test_true_pfs, y_test_baselinePred)
auc_baseline = np.round(roc_auc_score(bY_test_true_pfs, y_test_baselinePred_probs),2)

val_stats_transfer = get_stats(bY_test_true_pfs, y_test_transferPred)
auc_transfer = np.round(roc_auc_score(bY_test_true_pfs, y_test_transferPred_probs),2)

results_df = (pd.DataFrame({'Experiment': ['Baseline: MMRF RNA-Seq','Cell Perturbation Transfer'],
                            'Latent Dim.' : [128, 128],
                        'AUC': [auc_baseline,auc_transfer],
                      'Accuracy': [val_stats_baseline[0],val_stats_transfer[0]],
                            'F1': [val_stats_baseline[3],val_stats_transfer[3]],
                      'Precision': [val_stats_baseline[1],val_stats_transfer[1]],
                      'Recall': [val_stats_baseline[2],val_stats_transfer[2]]},
                      index=[0,1]))

display(results_df)
# Out:
#                    Experiment  Latent Dim.   AUC  Accuracy    F1  Precision  \
# 0      Baseline: MMRF RNA-Seq          128  0.58      0.58  0.65       0.62
# 1  Cell Perturbation Transfer          128  0.52      0.59  0.73       0.59
#
#    Recall
# 0    0.69
# 1    0.96

# %%
print(results_df.to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#                 Experiment &  Latent Dim. &  AUC &  Accuracy &   F1 &  Precision &  Recall \\
# \midrule
#     Baseline: MMRF RNA-Seq &          128 & 0.58 &      0.58 & 0.65 &       0.62 &    0.69 \\
# Cell Perturbation Transfer &          128 & 0.52 &      0.59 & 0.73 &       0.59 &    0.96 \\
# \bottomrule
# \end{tabular}
