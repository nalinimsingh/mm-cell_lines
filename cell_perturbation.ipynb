# %% [markdown]
# # Multi-task learning from cell line perturbation

# %% [markdown]
# * Authors: Eshika Saxena, Doris Fu
# * Objective: Implement and train multi-task classifier model to predict positive/negative cell viability score from encoded cell line RNA-seq profile. Fine-tune the pre-trained multi-task classifier model on patient data for patient long/short term pfs classification.

# %% [markdown]
# ## Load libraries

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

import os 
import shutil

import copy

import tensorflow as tf
import tensorflow.keras as K

from itertools import cycle

from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LinearRegression

import CCLE_utils
import MMRF_utils

# %%
tf.random.set_seed(221)

# %%
# directory containing raw CCLE and MMRF data
data_dir = '/Users/eshikasaxena/Documents/MLHC/mm-cell_lines/data/'

# %% [markdown]
# ## Load embeddings for cell line (CCLE) data from AE trained on MMRF data

# %%
with pd.HDFStore('normalized_embeddings.h5') as store:
    print(store.keys())
# Out:
# ['/ccle_test_ccleae', '/ccle_test_combinedae', '/ccle_test_mmrfae', '/ccle_train_ccleae', '/ccle_train_combinedae', '/ccle_train_mmrfae', '/ccle_valid_ccleae', '/ccle_valid_combinedae', '/ccle_valid_mmrfae', '/mmrf_test_ccleae', '/mmrf_test_combinedae', '/mmrf_test_mmrfae', '/mmrf_train_ccleae', '/mmrf_train_combinedae', '/mmrf_train_mmrfae', '/mmrf_valid_ccleae', '/mmrf_valid_combinedae', '/mmrf_valid_mmrfae']

# %%
X_train = pd.read_hdf("normalized_embeddings.h5", key = 'ccle_train_mmrfae', index_col=1)
X_train = X_train.set_index(X_train.iloc[:, 0])
X_train = X_train.iloc[: , 1:]

X_val = pd.read_hdf("normalized_embeddings.h5", key = 'ccle_valid_mmrfae', index_col=1)
X_val = X_val.set_index(X_val.iloc[:, 0])
X_val = X_val.iloc[: , 1:]

X_test = pd.read_hdf("normalized_embeddings.h5", key = 'ccle_test_mmrfae', index_col=1)
X_test = X_test.set_index(X_test.iloc[:, 0])
X_test = X_test.iloc[: , 1:]

# %%
print('AE Embeddings for cell line data')
print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# AE Embeddings for cell line data
# (964, 128) (138, 128) (276, 128)

# %% [markdown]
# ## Load and preprocess cell viability data

# %% [markdown]
# * Only keep IDs that are in both RNA-seq and CRISPR knockout.
# * Restrict knockout cell viability scores to 13 genes of interest.
# * Only keep RNA seq cols that map to Ensembl IDs.

# %%
rnaseq = pd.read_csv(os.path.join(data_dir,'CCLE_expression.csv'))
rnaseq = rnaseq.rename(columns={'Unnamed: 0': 'DepMap_ID'})

crispr = pd.read_csv(os.path.join(data_dir,'Achilles_gene_effect.csv'))

# %%
ids = list(set(crispr.DepMap_ID).intersection(set(rnaseq.DepMap_ID)))

print(len(ids))
# Out:
# 800

# %%
# genes of interest
genes = [col for col in crispr.columns if 'PSMB' in col or 'IKZF1' in col or 'IKZF3' in col]

print(len(genes))
print(genes)
# Out:
# 13
# ['IKZF1 (10320)', 'IKZF3 (22806)', 'PSMB1 (5689)', 'PSMB10 (5699)', 'PSMB11 (122706)', 'PSMB2 (5690)', 'PSMB3 (5691)', 'PSMB4 (5692)', 'PSMB5 (5693)', 'PSMB6 (5694)', 'PSMB7 (5695)', 'PSMB8 (5696)', 'PSMB9 (5698)']

# %%
crispr = crispr[crispr.DepMap_ID.isin(ids)][genes + ['DepMap_ID']]

print(len(crispr))
print(len(crispr.columns))
# Out:
# 800
# 14

# %%
mapping = pd.read_csv('Ensembl_HGNC_map_042421.csv')
cols_to_keep = ['DepMap_ID'] + list(mapping.HGNC_ID) 
rnaseq = rnaseq[cols_to_keep]
rnaseq = rnaseq[rnaseq.DepMap_ID.isin(ids)]

print(len(rnaseq))
# Out:
# 800

# %%
crispr_rnaseq_merged = rnaseq.merge(crispr, on='DepMap_ID')
print(len(crispr_rnaseq_merged))
# Out:
# 800

# %%
crispr_rnaseq_merged = crispr_rnaseq_merged.set_index(['DepMap_ID'])
response_cols = [col for col in crispr_rnaseq_merged.columns if '_y' in col]
crispr = crispr_rnaseq_merged[response_cols]

print(len(crispr))
# Out:
# 800

# %% [markdown]
# ## Preprocess and format cell line data for model training

# %% [markdown]
# * Limit to IDs present in both RNA-seq and in cell viability data
# * Convert cell viability scores to binary
# * One-hot encode binary outcomes

# %%
train_index = list(set(X_train.index).intersection(crispr.index))
val_index = list(set(X_val.index).intersection(crispr.index))
test_index = list(set(X_test.index).intersection(crispr.index))

# %%
X_train = X_train.loc[train_index]
X_val = X_val.loc[val_index]
X_test = X_test.loc[test_index]

# %%
Y_train = crispr.loc[train_index]
Y_val = crispr.loc[val_index]
Y_test = crispr.loc[test_index]

# binary outcome used for classifier; positive = 1, negative = 0
bY_train = (Y_train >0).astype(int)
bY_val = (Y_val >0).astype(int)
bY_test = (Y_test >0).astype(int)

# onehot encode binary outcomes
bY_train_oneHot = K.utils.to_categorical(bY_train, 2)
bY_val_oneHot = K.utils.to_categorical(bY_val, 2)
bY_test_oneHot = K.utils.to_categorical(bY_test, 2)

# %%
print('CCLE RNA-seq and Cell Viability Data')
print('Train', X_train.shape, bY_train_oneHot.shape)
print('Val', X_val.shape, bY_val_oneHot.shape)
print('Test', X_test.shape, bY_test_oneHot.shape)
# Out:
# CCLE RNA-seq and Cell Viability Data
# Train (559, 128) (559, 13, 2)
# Val (77, 128) (77, 13, 2)
# Test (165, 128) (165, 13, 2)

# %% [markdown]
# ## Load embeddings for patient (MMRF) data from AE trained on MMRF data

# %%
X_train_pt = pd.read_hdf("normalized_embeddings.h5", key = 'mmrf_train_mmrfae', index_col=1)
X_train_pt = X_train_pt.set_index(X_train_pt.iloc[:, 0])
X_train_pt = X_train_pt.iloc[: , 1:]

X_val_pt = pd.read_hdf("normalized_embeddings.h5", key = 'mmrf_valid_mmrfae', index_col=1)
X_val_pt = X_val_pt.set_index(X_val_pt.iloc[:, 0])
X_val_pt = X_val_pt.iloc[: , 1:]

X_test_pt = pd.read_hdf("normalized_embeddings.h5", key = 'mmrf_test_mmrfae', index_col=1)
X_test_pt = X_test_pt.set_index(X_test_pt.iloc[:, 0])
X_test_pt = X_test_pt.iloc[: , 1:]

# %%
print('AE Embeddings for patient data')
print(X_train_pt.shape, X_val_pt.shape, X_test_pt.shape)
# Out:
# AE Embeddings for patient data
# (341, 128) (126, 128) (184, 128)

# %% [markdown]
# ## Load and preprocess PFS data

# %%
for ind in [1]:
    data_filename = os.path.join(data_dir,'cleaned_mm%d_2mos_pfs_ind.pkl'%(ind))
    train, test, valid = MMRF_utils.get_train_test_valid(data_filename, ind, show_features=False)

    print('\nPreprocess patient data in MMRF')
    train_df = MMRF_utils.preprocess_patient_data(train, num_clin_visits=1)  
    print('Train', train_df.shape)

    valid_df = MMRF_utils.preprocess_patient_data(valid, num_clin_visits=1)  
    print('Val', valid_df.shape)

    test_df = MMRF_utils.preprocess_patient_data(test, num_clin_visits=1)  
    print('Test', test_df.shape)
# Out:
# loading from: /Users/eshikasaxena/Documents/MLHC/mm-cell_lines/data/cleaned_mm1_2mos_pfs_ind.pkl
#
# Preprocess patient data in MMRF
# Keep first 1 clinical visits.
# Train (461, 43)
# Keep first 1 clinical visits.
# Val (161, 43)
# Keep first 1 clinical visits.
# Test (214, 43)

# %%
train_pfs = train_df[['pids','pfs']]
train_pfs = train_pfs.set_index('pids')

val_pfs = valid_df[['pids','pfs']]
val_pfs = val_pfs.set_index('pids')

test_pfs = test_df[['pids','pfs']]
test_pfs = test_pfs.set_index('pids')

# %% [markdown]
# ## Preprocess and format patient data for model training

# %%
train_index_pt = list(set(X_train_pt.index).intersection(train_pfs.index))
val_index_pt = list(set(X_val_pt.index).intersection(val_pfs.index))
test_index_pt = list(set(X_test_pt.index).intersection(test_pfs.index))

# %%
X_train_pt = X_train_pt.loc[train_index_pt]
X_val_pt = X_val_pt.loc[val_index_pt]
X_test_pt = X_test_pt.loc[test_index_pt]

# %%
Y_train_pfs = train_pfs.loc[train_index_pt]
Y_val_pfs = val_pfs.loc[val_index_pt]
Y_test_pfs = test_pfs.loc[test_index_pt]

# binary outcome used for classifier; greater than 12 = 1, less than or equal to 12 = 0
bY_train_pfs = (Y_train_pfs >12).astype(int)
bY_val_pfs = (Y_val_pfs >12).astype(int)
bY_test_pfs = (Y_test_pfs >12).astype(int)

# onehot encode binary outcomes
bY_train_pfs_oneHot = K.utils.to_categorical(bY_train_pfs, 2)
bY_val_pfs_oneHot = K.utils.to_categorical(bY_val_pfs, 2)
bY_test_pfs_oneHot = K.utils.to_categorical(bY_test_pfs, 2)

# %%
print('MMRF RNA-seq and PFS Data')
print('Train', X_train_pt.shape, bY_train_pfs_oneHot.shape)
print('Val', X_val_pt.shape, bY_val_pfs_oneHot.shape)
print('Test', X_test_pt.shape, bY_test_pfs_oneHot.shape)
# Out:
# MMRF RNA-seq and PFS Data
# Train (313, 128) (313, 2)
# Val (97, 128) (97, 2)
# Test (142, 128) (142, 2)

# %% [markdown]
# ## EDA: Plotting cell viability score distributions

# %%
fig, ax = plt.subplots(4, 4, figsize = (15,12))

ax_new = Y_train.hist(bins=10, ax=ax.ravel()[:13])
for i in range(13):
    ax_new[i].set_xlabel("Cell Viability")
    ax_new[i].set_ylabel("Cell Lines") 
    ax_new[i].set_title(f"Distribution for {Y_train.columns[i].split(' ')[0]}")
    ax_new[i].set_xlim(-1*4,4)
    ax_new[i].grid(False)

plt.tight_layout()

# %% [markdown]
# ## Define classifier architecture

# %%
def generate_classifier(N_in):
    inputs = K.layers.Input(shape = (N_in,))
    x = K.layers.Dense(64, activation='relu', kernel_regularizer=K.regularizers.l2(l=0.01))(inputs)
    x = K.layers.Dense(32, activation='relu', kernel_regularizer=K.regularizers.l2(l=0.01))(x)   
    y1 = K.layers.Dense(2, activation='softmax', kernel_regularizer=K.regularizers.l2(l=0.01), name='y1')(x)
    y2 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y2')(x)
    y3 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y3')(x)
    y4 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y4')(x)
    y5 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y5')(x)
    y6 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y6')(x)
    y7 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y7')(x)
    y8 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y8')(x)
    y9 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y9')(x)
    y10 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y10')(x)
    y11 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y11')(x)
    y12 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y12')(x)
    y13 = K.layers.Dense(2, activation='softmax',kernel_regularizer=K.regularizers.l2(l=0.01), name='y13')(x)
    
    combined = [y1,y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13]
    tensors = [tf.expand_dims(i, axis=1) for i in combined]
    output = K.layers.concatenate(tensors, axis=1)
    
    model = K.models.Model(inputs = inputs, outputs = output)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
def plot_loss(perf_dict):
    fig = plt.figure(figsize=(15,10))
    ax1 = plt.subplot(2,2,1)
    ax2 = plt.subplot(2,2,2)
    loss = perf_dict['loss']
    val_loss = perf_dict['val_loss']
    ax1.plot(loss)
    ax2.plot(val_loss)
    ax1.set_xlabel('epochs')
    ax2.set_xlabel('epochs')

    ax1.set_ylabel('loss')
    ax2.set_ylabel('val_loss')
    plt.show()

# %% [markdown]
# ## Train Classifier Model
#
# * Predicts a binarized cell viability score for 13 different genes that were perturbed using CCLE embeddings from autoencoder trained on MMRF data

# %%
classifier = generate_classifier(X_train.shape[1])

print("Input", classifier.input_shape)
print("Output", classifier.output_shape)
classifier.summary()
# Out:
# Input (None, 128)
# Output (None, 13, 2)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           2080        dense[0][0]
# __________________________________________________________________________________________________
# y1 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y2 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y3 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y4 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y5 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y6 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y7 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y8 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y9 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y10 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y11 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y12 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y13 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 1, 2)         0           y1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 1, 2)         0           y2[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_2 (TFOpLambda)   (None, 1, 2)         0           y3[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_3 (TFOpLambda)   (None, 1, 2)         0           y4[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_4 (TFOpLambda)   (None, 1, 2)         0           y5[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_5 (TFOpLambda)   (None, 1, 2)         0           y6[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_6 (TFOpLambda)   (None, 1, 2)         0           y7[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_7 (TFOpLambda)   (None, 1, 2)         0           y8[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_8 (TFOpLambda)   (None, 1, 2)         0           y9[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_9 (TFOpLambda)   (None, 1, 2)         0           y10[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_10 (TFOpLambda)  (None, 1, 2)         0           y11[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_11 (TFOpLambda)  (None, 1, 2)         0           y12[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_12 (TFOpLambda)  (None, 1, 2)         0           y13[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 13, 2)        0           tf.expand_dims[0][0]
#                                                                  tf.expand_dims_1[0][0]
#                                                                  tf.expand_dims_2[0][0]
#                                                                  tf.expand_dims_3[0][0]
#                                                                  tf.expand_dims_4[0][0]
#                                                                  tf.expand_dims_5[0][0]
#                                                                  tf.expand_dims_6[0][0]
#                                                                  tf.expand_dims_7[0][0]
#                                                                  tf.expand_dims_8[0][0]
#                                                                  tf.expand_dims_9[0][0]
#                                                                  tf.expand_dims_10[0][0]
#                                                                  tf.expand_dims_11[0][0]
#                                                                  tf.expand_dims_12[0][0]
# ==================================================================================================
# Total params: 11,194
# Trainable params: 11,194
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
classifier_history = classifier.fit(X_train,bY_train_oneHot,epochs=100, validation_data=(X_val, bY_val_oneHot),verbose=0)

# %%
plot_loss(classifier_history.history)

# %%
y_train_classifierPred = np.array(classifier.predict(X_train))[:,:,1]
y_test_classifierPred = np.array(classifier.predict(X_test))[:,:,1]

bY_test_true = bY_test_oneHot[:,:,1]
bY_train_true = bY_train_oneHot[:,:,1]

print(y_train_classifierPred.shape, y_test_classifierPred.shape)
print(bY_train_true.shape, bY_test_true.shape)
# Out:
# (559, 13) (165, 13)
# (559, 13) (165, 13)

# %%
n_classes = 13
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(bY_test_true[:, i], y_test_classifierPred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(bY_test_true.ravel(), y_test_classifierPred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
# Out:
# /Users/eshikasaxena/miniconda3/envs/cs109b/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
# /Users/eshikasaxena/miniconda3/envs/cs109b/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
# /Users/eshikasaxena/miniconda3/envs/cs109b/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
# /Users/eshikasaxena/miniconda3/envs/cs109b/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
# /Users/eshikasaxena/miniconda3/envs/cs109b/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

plt.plot([0, 1], [0, 1], 'k--', lw=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Average ROC Curves')
plt.legend(loc="lower right")
plt.show()

# %%
fig, axes = plt.subplots(5, 3, figsize=(15,15))
lw = 2

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, ax, color in zip(range(13), axes.ravel(), colors):
    ax.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
    ax.plot([0, 1], [0, 1], 'k--', lw=lw)
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(f'ROC Curve for Class {i}')
    ax.legend(loc="lower right")

plt.tight_layout()

# %% [markdown]
# ## Fine-tuning on patient data
# * Freeze network except the last layer
# * Fine-tune on MMRF patient RNA-seq embeddings from the same autoencoder to predict binarized progression free survival (PFS > 12 or not)

# %%
classifier.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           8256        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           2080        dense[0][0]
# __________________________________________________________________________________________________
# y1 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y2 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y3 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y4 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y5 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y6 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y7 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y8 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y9 (Dense)                      (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y10 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y11 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y12 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# y13 (Dense)                     (None, 2)            66          dense_1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims (TFOpLambda)     (None, 1, 2)         0           y1[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 1, 2)         0           y2[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_2 (TFOpLambda)   (None, 1, 2)         0           y3[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_3 (TFOpLambda)   (None, 1, 2)         0           y4[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_4 (TFOpLambda)   (None, 1, 2)         0           y5[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_5 (TFOpLambda)   (None, 1, 2)         0           y6[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_6 (TFOpLambda)   (None, 1, 2)         0           y7[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_7 (TFOpLambda)   (None, 1, 2)         0           y8[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_8 (TFOpLambda)   (None, 1, 2)         0           y9[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_9 (TFOpLambda)   (None, 1, 2)         0           y10[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_10 (TFOpLambda)  (None, 1, 2)         0           y11[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_11 (TFOpLambda)  (None, 1, 2)         0           y12[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_12 (TFOpLambda)  (None, 1, 2)         0           y13[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 13, 2)        0           tf.expand_dims[0][0]
#                                                                  tf.expand_dims_1[0][0]
#                                                                  tf.expand_dims_2[0][0]
#                                                                  tf.expand_dims_3[0][0]
#                                                                  tf.expand_dims_4[0][0]
#                                                                  tf.expand_dims_5[0][0]
#                                                                  tf.expand_dims_6[0][0]
#                                                                  tf.expand_dims_7[0][0]
#                                                                  tf.expand_dims_8[0][0]
#                                                                  tf.expand_dims_9[0][0]
#                                                                  tf.expand_dims_10[0][0]
#                                                                  tf.expand_dims_11[0][0]
#                                                                  tf.expand_dims_12[0][0]
# ==================================================================================================
# Total params: 11,194
# Trainable params: 11,194
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# freeze layers
classifier.layers[0].trainable = False
classifier.layers[1].trainable = False
classifier.layers[2].trainable = False

transfer = classifier.layers[2].output

final_output = K.layers.Dense(2, activation='softmax', kernel_regularizer=K.regularizers.l2(l=0.01), name='final')(transfer)

transfer_model = K.models.Model(inputs=classifier.input, outputs=final_output)

transfer_model.compile(optimizer='adam',
                  loss='categorical_crossentropy', metrics=['accuracy'])

print(transfer_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128)]             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# final (Dense)                (None, 2)                 66
# =================================================================
# Total params: 10,402
# Trainable params: 66
# Non-trainable params: 10,336
# _________________________________________________________________
# None

# %%
history_pt = transfer_model.fit(X_train_pt, bY_train_pfs_oneHot, epochs=100, validation_data=(X_val_pt, bY_val_pfs_oneHot))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 23ms/step - loss: 1.4764 - accuracy: 0.5038 - val_loss: 0.9453 - val_accuracy: 0.5979
# Epoch 2/100
# 10/10 [==============================] - 0s 15ms/step - loss: 1.2024 - accuracy: 0.5833 - val_loss: 0.9206 - val_accuracy: 0.6289
# Epoch 3/100
# 10/10 [==============================] - 0s 16ms/step - loss: 1.2514 - accuracy: 0.5387 - val_loss: 0.9000 - val_accuracy: 0.6392
# Epoch 4/100
# 10/10 [==============================] - 0s 11ms/step - loss: 1.0910 - accuracy: 0.4841 - val_loss: 0.8835 - val_accuracy: 0.6289
# Epoch 5/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1557 - accuracy: 0.5016 - val_loss: 0.8684 - val_accuracy: 0.6289
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.1936 - accuracy: 0.5358 - val_loss: 0.8561 - val_accuracy: 0.6392
# Epoch 7/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3907 - accuracy: 0.4978 - val_loss: 0.8448 - val_accuracy: 0.6392
# Epoch 8/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0072 - accuracy: 0.4892 - val_loss: 0.8359 - val_accuracy: 0.6392
# Epoch 9/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0867 - accuracy: 0.5152 - val_loss: 0.8251 - val_accuracy: 0.6495
# Epoch 10/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0709 - accuracy: 0.5170 - val_loss: 0.8166 - val_accuracy: 0.6701
# Epoch 11/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0318 - accuracy: 0.5430 - val_loss: 0.8079 - val_accuracy: 0.6701
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0829 - accuracy: 0.5439 - val_loss: 0.7997 - val_accuracy: 0.6804
# Epoch 13/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0850 - accuracy: 0.5497 - val_loss: 0.7913 - val_accuracy: 0.6701
# Epoch 14/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9813 - accuracy: 0.5709 - val_loss: 0.7839 - val_accuracy: 0.6804
# Epoch 15/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9553 - accuracy: 0.5551 - val_loss: 0.7782 - val_accuracy: 0.6907
# Epoch 16/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0209 - accuracy: 0.5465 - val_loss: 0.7718 - val_accuracy: 0.7113
# Epoch 17/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9396 - accuracy: 0.5552 - val_loss: 0.7650 - val_accuracy: 0.6804
# Epoch 18/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9408 - accuracy: 0.5762 - val_loss: 0.7587 - val_accuracy: 0.6804
# Epoch 19/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9472 - accuracy: 0.5155 - val_loss: 0.7534 - val_accuracy: 0.6804
# Epoch 20/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9271 - accuracy: 0.5876 - val_loss: 0.7482 - val_accuracy: 0.6804
# Epoch 21/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9715 - accuracy: 0.5854 - val_loss: 0.7433 - val_accuracy: 0.6598
# Epoch 22/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.8802 - accuracy: 0.5840 - val_loss: 0.7397 - val_accuracy: 0.6495
# Epoch 23/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8683 - accuracy: 0.6368 - val_loss: 0.7355 - val_accuracy: 0.6495
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8882 - accuracy: 0.6078 - val_loss: 0.7307 - val_accuracy: 0.6598
# Epoch 25/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.8346 - accuracy: 0.6033 - val_loss: 0.7274 - val_accuracy: 0.6701
# Epoch 26/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9257 - accuracy: 0.5928 - val_loss: 0.7237 - val_accuracy: 0.6701
# Epoch 27/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8900 - accuracy: 0.5864 - val_loss: 0.7213 - val_accuracy: 0.6907
# Epoch 28/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.8394 - accuracy: 0.6494 - val_loss: 0.7179 - val_accuracy: 0.6907
# Epoch 29/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8250 - accuracy: 0.6680 - val_loss: 0.7153 - val_accuracy: 0.6907
# Epoch 30/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9157 - accuracy: 0.6203 - val_loss: 0.7112 - val_accuracy: 0.6907
# Epoch 31/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8397 - accuracy: 0.6695 - val_loss: 0.7092 - val_accuracy: 0.6701
# Epoch 32/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8361 - accuracy: 0.6489 - val_loss: 0.7070 - val_accuracy: 0.6701
# Epoch 33/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7846 - accuracy: 0.6390 - val_loss: 0.7061 - val_accuracy: 0.6598
# Epoch 34/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8386 - accuracy: 0.6217 - val_loss: 0.7033 - val_accuracy: 0.6598
# Epoch 35/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8039 - accuracy: 0.6458 - val_loss: 0.7011 - val_accuracy: 0.6598
# Epoch 36/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.8122 - accuracy: 0.6457 - val_loss: 0.6994 - val_accuracy: 0.6495
# Epoch 37/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8320 - accuracy: 0.6499 - val_loss: 0.6979 - val_accuracy: 0.6495
# Epoch 38/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7912 - accuracy: 0.6761 - val_loss: 0.6967 - val_accuracy: 0.6495
# Epoch 39/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7836 - accuracy: 0.6419 - val_loss: 0.6955 - val_accuracy: 0.6495
# Epoch 40/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7427 - accuracy: 0.6929 - val_loss: 0.6945 - val_accuracy: 0.6495
# Epoch 41/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7793 - accuracy: 0.6131 - val_loss: 0.6936 - val_accuracy: 0.6495
# Epoch 42/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7543 - accuracy: 0.6613 - val_loss: 0.6918 - val_accuracy: 0.6495
# Epoch 43/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7686 - accuracy: 0.6407 - val_loss: 0.6911 - val_accuracy: 0.6495
# Epoch 44/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8165 - accuracy: 0.6039 - val_loss: 0.6907 - val_accuracy: 0.6495
# Epoch 45/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7384 - accuracy: 0.6527 - val_loss: 0.6903 - val_accuracy: 0.6392
# Epoch 46/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8012 - accuracy: 0.6264 - val_loss: 0.6895 - val_accuracy: 0.6392
# Epoch 47/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7877 - accuracy: 0.6109 - val_loss: 0.6894 - val_accuracy: 0.6392
# Epoch 48/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7659 - accuracy: 0.6290 - val_loss: 0.6890 - val_accuracy: 0.6392
# Epoch 49/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7452 - accuracy: 0.6505 - val_loss: 0.6886 - val_accuracy: 0.6392
# Epoch 50/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7223 - accuracy: 0.6722 - val_loss: 0.6883 - val_accuracy: 0.6392
# Epoch 51/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7326 - accuracy: 0.6348 - val_loss: 0.6881 - val_accuracy: 0.6392
# Epoch 52/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7330 - accuracy: 0.6195 - val_loss: 0.6879 - val_accuracy: 0.6392
# Epoch 53/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7066 - accuracy: 0.6568 - val_loss: 0.6878 - val_accuracy: 0.6392
# Epoch 54/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7239 - accuracy: 0.6565 - val_loss: 0.6879 - val_accuracy: 0.6392
# Epoch 55/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7424 - accuracy: 0.6246 - val_loss: 0.6875 - val_accuracy: 0.6289
# Epoch 56/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7289 - accuracy: 0.6618 - val_loss: 0.6874 - val_accuracy: 0.6289
# Epoch 57/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7088 - accuracy: 0.6860 - val_loss: 0.6873 - val_accuracy: 0.6289
# Epoch 58/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7515 - accuracy: 0.6295 - val_loss: 0.6876 - val_accuracy: 0.6392
# Epoch 59/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7240 - accuracy: 0.6509 - val_loss: 0.6879 - val_accuracy: 0.6392
# Epoch 60/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6897 - accuracy: 0.6933 - val_loss: 0.6882 - val_accuracy: 0.6495
# Epoch 61/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7591 - accuracy: 0.6024 - val_loss: 0.6879 - val_accuracy: 0.6392
# Epoch 62/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7030 - accuracy: 0.6611 - val_loss: 0.6884 - val_accuracy: 0.6392
# Epoch 63/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7029 - accuracy: 0.6659 - val_loss: 0.6882 - val_accuracy: 0.6392
# Epoch 64/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6788 - accuracy: 0.7232 - val_loss: 0.6881 - val_accuracy: 0.6392
# Epoch 65/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7078 - accuracy: 0.6822 - val_loss: 0.6883 - val_accuracy: 0.6392
# Epoch 66/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7041 - accuracy: 0.6416 - val_loss: 0.6888 - val_accuracy: 0.6392
# Epoch 67/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7289 - accuracy: 0.6333 - val_loss: 0.6889 - val_accuracy: 0.6392
# Epoch 68/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6972 - accuracy: 0.6693 - val_loss: 0.6897 - val_accuracy: 0.6392
# Epoch 69/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7239 - accuracy: 0.6589 - val_loss: 0.6900 - val_accuracy: 0.6289
# Epoch 70/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7202 - accuracy: 0.6615 - val_loss: 0.6895 - val_accuracy: 0.6392
# Epoch 71/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6836 - accuracy: 0.6936 - val_loss: 0.6892 - val_accuracy: 0.6392
# Epoch 72/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6934 - accuracy: 0.6931 - val_loss: 0.6901 - val_accuracy: 0.6289
# Epoch 73/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6967 - accuracy: 0.6662 - val_loss: 0.6904 - val_accuracy: 0.6289
# Epoch 74/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6999 - accuracy: 0.6735 - val_loss: 0.6903 - val_accuracy: 0.6289
# Epoch 75/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7063 - accuracy: 0.6578 - val_loss: 0.6907 - val_accuracy: 0.6392
# Epoch 76/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6936 - accuracy: 0.6849 - val_loss: 0.6909 - val_accuracy: 0.6392
# Epoch 77/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6864 - accuracy: 0.7071 - val_loss: 0.6913 - val_accuracy: 0.6392
# Epoch 78/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7289 - accuracy: 0.6332 - val_loss: 0.6913 - val_accuracy: 0.6392
# Epoch 79/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6732 - accuracy: 0.7187 - val_loss: 0.6915 - val_accuracy: 0.6392
# Epoch 80/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7052 - accuracy: 0.6584 - val_loss: 0.6921 - val_accuracy: 0.6392
# Epoch 81/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6678 - accuracy: 0.7143 - val_loss: 0.6923 - val_accuracy: 0.6392
# Epoch 82/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6973 - accuracy: 0.6625 - val_loss: 0.6925 - val_accuracy: 0.6392
# Epoch 83/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7114 - accuracy: 0.6404 - val_loss: 0.6922 - val_accuracy: 0.6392
# Epoch 84/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6982 - accuracy: 0.6544 - val_loss: 0.6929 - val_accuracy: 0.6392
# Epoch 85/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6732 - accuracy: 0.7029 - val_loss: 0.6933 - val_accuracy: 0.6392
# Epoch 86/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7048 - accuracy: 0.6579 - val_loss: 0.6937 - val_accuracy: 0.6392
# Epoch 87/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7042 - accuracy: 0.6579 - val_loss: 0.6944 - val_accuracy: 0.6392
# Epoch 88/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7114 - accuracy: 0.6524 - val_loss: 0.6939 - val_accuracy: 0.6392
# Epoch 89/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6797 - accuracy: 0.6918 - val_loss: 0.6947 - val_accuracy: 0.6392
# Epoch 90/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6922 - accuracy: 0.6814 - val_loss: 0.6955 - val_accuracy: 0.6392
# Epoch 91/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6866 - accuracy: 0.6760 - val_loss: 0.6950 - val_accuracy: 0.6392
# Epoch 92/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6998 - accuracy: 0.6782 - val_loss: 0.6950 - val_accuracy: 0.6495
# Epoch 93/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6912 - accuracy: 0.6766 - val_loss: 0.6954 - val_accuracy: 0.6392
# Epoch 94/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7009 - accuracy: 0.6790 - val_loss: 0.6955 - val_accuracy: 0.6495
# Epoch 95/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6841 - accuracy: 0.7066 - val_loss: 0.6959 - val_accuracy: 0.6392
# Epoch 96/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6794 - accuracy: 0.6939 - val_loss: 0.6961 - val_accuracy: 0.6392
# Epoch 97/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6989 - accuracy: 0.6725 - val_loss: 0.6966 - val_accuracy: 0.6392
# Epoch 98/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7111 - accuracy: 0.6670 - val_loss: 0.6966 - val_accuracy: 0.6392
# Epoch 99/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6756 - accuracy: 0.7067 - val_loss: 0.6970 - val_accuracy: 0.6392
# Epoch 100/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6489 - accuracy: 0.7373 - val_loss: 0.6974 - val_accuracy: 0.6392

# %%
plot_loss(history_pt.history)

# %%
y_train_transferPred_probs = np.array(transfer_model.predict(X_train_pt))[:,1]
y_test_transferPred_probs = np.array(transfer_model.predict(X_test_pt))[:,1]

y_train_transferPred = np.where(y_train_transferPred_probs > 0.5, 1, 0)
y_test_transferPred = np.where(y_test_transferPred_probs > 0.5, 1, 0)

bY_train_true_pfs = bY_train_pfs_oneHot[:,1]
bY_test_true_pfs = bY_test_pfs_oneHot[:,1]

print(y_train_transferPred.shape, y_test_transferPred.shape)
print(bY_train_true_pfs.shape, bY_test_true_pfs.shape)
# Out:
# (313,) (142,)
# (313,) (142,)

# %% [markdown]
# ## Baseline Model
# * Same architecture (2 dense layers and a head) but only trained on the patient RNA-seq embeddings, not cell line data, for binarized PFS prediction

# %%
inputs = K.layers.Input(shape = (128,))
x = K.layers.Dense(64, activation='relu', kernel_regularizer=K.regularizers.l2(l=0.01))(inputs)
x = K.layers.Dense(32, activation='relu', kernel_regularizer=K.regularizers.l2(l=0.01))(x)

output = K.layers.Dense(2, activation='softmax', kernel_regularizer=K.regularizers.l2(l=0.01), name='final')(x)

baseline_model = K.models.Model(inputs=inputs, outputs=output)

baseline_model.compile(optimizer='adam',
                  loss='categorical_crossentropy', metrics=['accuracy'])

print(baseline_model.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128)]             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# final (Dense)                (None, 2)                 66
# =================================================================
# Total params: 10,402
# Trainable params: 10,402
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history_baseline = baseline_model.fit(X_train_pt, bY_train_pfs_oneHot, epochs=100, validation_data=(X_val_pt, bY_val_pfs_oneHot))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 25ms/step - loss: 5.3545 - accuracy: 0.5036 - val_loss: 3.5164 - val_accuracy: 0.4433
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 3.3334 - accuracy: 0.5381 - val_loss: 3.0339 - val_accuracy: 0.5464
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 2.2822 - accuracy: 0.7225 - val_loss: 2.5897 - val_accuracy: 0.5052
# Epoch 4/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8588 - accuracy: 0.7499 - val_loss: 2.4232 - val_accuracy: 0.5361
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.6658 - accuracy: 0.7728 - val_loss: 2.4041 - val_accuracy: 0.5258
# Epoch 6/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.4761 - accuracy: 0.8853 - val_loss: 2.3913 - val_accuracy: 0.5361
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.3689 - accuracy: 0.9273 - val_loss: 2.3695 - val_accuracy: 0.5464
# Epoch 8/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3476 - accuracy: 0.9221 - val_loss: 2.3573 - val_accuracy: 0.5361
# Epoch 9/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3097 - accuracy: 0.9341 - val_loss: 2.3094 - val_accuracy: 0.5567
# Epoch 10/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2416 - accuracy: 0.9490 - val_loss: 2.2987 - val_accuracy: 0.5464
# Epoch 11/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2106 - accuracy: 0.9637 - val_loss: 2.3076 - val_accuracy: 0.5670
# Epoch 12/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1663 - accuracy: 0.9776 - val_loss: 2.2757 - val_accuracy: 0.5670
# Epoch 13/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1563 - accuracy: 0.9833 - val_loss: 2.2722 - val_accuracy: 0.5670
# Epoch 14/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1506 - accuracy: 0.9818 - val_loss: 2.2616 - val_accuracy: 0.5670
# Epoch 15/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1455 - accuracy: 0.9604 - val_loss: 2.2556 - val_accuracy: 0.5670
# Epoch 16/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0916 - accuracy: 0.9662 - val_loss: 2.2501 - val_accuracy: 0.5464
# Epoch 17/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0725 - accuracy: 0.9979 - val_loss: 2.2324 - val_accuracy: 0.5464
# Epoch 18/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0557 - accuracy: 0.9880 - val_loss: 2.2524 - val_accuracy: 0.5670
# Epoch 19/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0492 - accuracy: 0.9901 - val_loss: 2.2170 - val_accuracy: 0.5464
# Epoch 20/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.0220 - accuracy: 0.9884 - val_loss: 2.2121 - val_accuracy: 0.5670
# Epoch 21/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0133 - accuracy: 0.9979 - val_loss: 2.1974 - val_accuracy: 0.5155
# Epoch 22/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9906 - accuracy: 0.9979 - val_loss: 2.1999 - val_accuracy: 0.5670
# Epoch 23/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9787 - accuracy: 1.0000 - val_loss: 2.1844 - val_accuracy: 0.5361
# Epoch 24/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9635 - accuracy: 1.0000 - val_loss: 2.1820 - val_accuracy: 0.5670
# Epoch 25/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9524 - accuracy: 1.0000 - val_loss: 2.1662 - val_accuracy: 0.5773
# Epoch 26/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9417 - accuracy: 1.0000 - val_loss: 2.1654 - val_accuracy: 0.5773
# Epoch 27/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9327 - accuracy: 1.0000 - val_loss: 2.1650 - val_accuracy: 0.5876
# Epoch 28/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9162 - accuracy: 1.0000 - val_loss: 2.1455 - val_accuracy: 0.5773
# Epoch 29/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9070 - accuracy: 1.0000 - val_loss: 2.1445 - val_accuracy: 0.5979
# Epoch 30/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8951 - accuracy: 1.0000 - val_loss: 2.1361 - val_accuracy: 0.5876
# Epoch 31/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8819 - accuracy: 1.0000 - val_loss: 2.1258 - val_accuracy: 0.5876
# Epoch 32/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8725 - accuracy: 1.0000 - val_loss: 2.1124 - val_accuracy: 0.5876
# Epoch 33/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.8639 - accuracy: 1.0000 - val_loss: 2.1154 - val_accuracy: 0.5876
# Epoch 34/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8514 - accuracy: 1.0000 - val_loss: 2.1001 - val_accuracy: 0.5876
# Epoch 35/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8447 - accuracy: 1.0000 - val_loss: 2.0983 - val_accuracy: 0.5979
# Epoch 36/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8308 - accuracy: 1.0000 - val_loss: 2.0907 - val_accuracy: 0.5979
# Epoch 37/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.8213 - accuracy: 1.0000 - val_loss: 2.0721 - val_accuracy: 0.5773
# Epoch 38/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8141 - accuracy: 1.0000 - val_loss: 2.0780 - val_accuracy: 0.5979
# Epoch 39/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8055 - accuracy: 1.0000 - val_loss: 2.0702 - val_accuracy: 0.5979
# Epoch 40/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7928 - accuracy: 1.0000 - val_loss: 2.0597 - val_accuracy: 0.5979
# Epoch 41/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7860 - accuracy: 1.0000 - val_loss: 2.0492 - val_accuracy: 0.5876
# Epoch 42/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7746 - accuracy: 1.0000 - val_loss: 2.0425 - val_accuracy: 0.5773
# Epoch 43/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7674 - accuracy: 1.0000 - val_loss: 2.0347 - val_accuracy: 0.5876
# Epoch 44/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7589 - accuracy: 1.0000 - val_loss: 2.0251 - val_accuracy: 0.5979
# Epoch 45/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7500 - accuracy: 1.0000 - val_loss: 2.0152 - val_accuracy: 0.5876
# Epoch 46/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7413 - accuracy: 1.0000 - val_loss: 2.0196 - val_accuracy: 0.5979
# Epoch 47/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7306 - accuracy: 1.0000 - val_loss: 2.0109 - val_accuracy: 0.5979
# Epoch 48/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7250 - accuracy: 1.0000 - val_loss: 1.9941 - val_accuracy: 0.5876
# Epoch 49/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7154 - accuracy: 1.0000 - val_loss: 1.9923 - val_accuracy: 0.5979
# Epoch 50/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7068 - accuracy: 1.0000 - val_loss: 1.9802 - val_accuracy: 0.5876
# Epoch 51/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6987 - accuracy: 1.0000 - val_loss: 1.9804 - val_accuracy: 0.5876
# Epoch 52/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6920 - accuracy: 1.0000 - val_loss: 1.9696 - val_accuracy: 0.5876
# Epoch 53/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6838 - accuracy: 1.0000 - val_loss: 1.9669 - val_accuracy: 0.5876
# Epoch 54/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6747 - accuracy: 1.0000 - val_loss: 1.9568 - val_accuracy: 0.5876
# Epoch 55/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6715 - accuracy: 1.0000 - val_loss: 1.9573 - val_accuracy: 0.6082
# Epoch 56/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6595 - accuracy: 1.0000 - val_loss: 1.9401 - val_accuracy: 0.5979
# Epoch 57/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6534 - accuracy: 1.0000 - val_loss: 1.9392 - val_accuracy: 0.5979
# Epoch 58/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6441 - accuracy: 1.0000 - val_loss: 1.9400 - val_accuracy: 0.5979
# Epoch 59/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6378 - accuracy: 1.0000 - val_loss: 1.9194 - val_accuracy: 0.5979
# Epoch 60/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6313 - accuracy: 1.0000 - val_loss: 1.9251 - val_accuracy: 0.5979
# Epoch 61/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6260 - accuracy: 1.0000 - val_loss: 1.9077 - val_accuracy: 0.6082
# Epoch 62/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6176 - accuracy: 1.0000 - val_loss: 1.9122 - val_accuracy: 0.6082
# Epoch 63/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6101 - accuracy: 1.0000 - val_loss: 1.8997 - val_accuracy: 0.5979
# Epoch 64/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6028 - accuracy: 1.0000 - val_loss: 1.9009 - val_accuracy: 0.6082
# Epoch 65/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5957 - accuracy: 1.0000 - val_loss: 1.8729 - val_accuracy: 0.6082
# Epoch 66/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5882 - accuracy: 1.0000 - val_loss: 1.8778 - val_accuracy: 0.5979
# Epoch 67/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5818 - accuracy: 1.0000 - val_loss: 1.8666 - val_accuracy: 0.5979
# Epoch 68/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5765 - accuracy: 1.0000 - val_loss: 1.8660 - val_accuracy: 0.5979
# Epoch 69/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5696 - accuracy: 1.0000 - val_loss: 1.8511 - val_accuracy: 0.5979
# Epoch 70/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5650 - accuracy: 1.0000 - val_loss: 1.8503 - val_accuracy: 0.5979
# Epoch 71/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5564 - accuracy: 1.0000 - val_loss: 1.8376 - val_accuracy: 0.5979
# Epoch 72/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5503 - accuracy: 1.0000 - val_loss: 1.8292 - val_accuracy: 0.5979
# Epoch 73/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5444 - accuracy: 1.0000 - val_loss: 1.8260 - val_accuracy: 0.5979
# Epoch 74/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5395 - accuracy: 1.0000 - val_loss: 1.8185 - val_accuracy: 0.6082
# Epoch 75/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5330 - accuracy: 1.0000 - val_loss: 1.8125 - val_accuracy: 0.5979
# Epoch 76/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5259 - accuracy: 1.0000 - val_loss: 1.8003 - val_accuracy: 0.5979
# Epoch 77/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5197 - accuracy: 1.0000 - val_loss: 1.7911 - val_accuracy: 0.6082
# Epoch 78/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5157 - accuracy: 1.0000 - val_loss: 1.7923 - val_accuracy: 0.6082
# Epoch 79/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5084 - accuracy: 1.0000 - val_loss: 1.7847 - val_accuracy: 0.6082
# Epoch 80/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5036 - accuracy: 1.0000 - val_loss: 1.7727 - val_accuracy: 0.6082
# Epoch 81/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4975 - accuracy: 1.0000 - val_loss: 1.7573 - val_accuracy: 0.5979
# Epoch 82/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4929 - accuracy: 1.0000 - val_loss: 1.7650 - val_accuracy: 0.6082
# Epoch 83/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4868 - accuracy: 1.0000 - val_loss: 1.7504 - val_accuracy: 0.5979
# Epoch 84/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4814 - accuracy: 1.0000 - val_loss: 1.7526 - val_accuracy: 0.5979
# Epoch 85/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4754 - accuracy: 1.0000 - val_loss: 1.7406 - val_accuracy: 0.5979
# Epoch 86/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4706 - accuracy: 1.0000 - val_loss: 1.7372 - val_accuracy: 0.5876
# Epoch 87/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4651 - accuracy: 1.0000 - val_loss: 1.7318 - val_accuracy: 0.5979
# Epoch 88/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4619 - accuracy: 1.0000 - val_loss: 1.7245 - val_accuracy: 0.5979
# Epoch 89/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4550 - accuracy: 1.0000 - val_loss: 1.7144 - val_accuracy: 0.5876
# Epoch 90/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4499 - accuracy: 1.0000 - val_loss: 1.7074 - val_accuracy: 0.5979
# Epoch 91/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4458 - accuracy: 1.0000 - val_loss: 1.7040 - val_accuracy: 0.5979
# Epoch 92/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4389 - accuracy: 1.0000 - val_loss: 1.7074 - val_accuracy: 0.5979
# Epoch 93/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4349 - accuracy: 1.0000 - val_loss: 1.6975 - val_accuracy: 0.5979
# Epoch 94/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4305 - accuracy: 1.0000 - val_loss: 1.6831 - val_accuracy: 0.5876
# Epoch 95/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4254 - accuracy: 1.0000 - val_loss: 1.6795 - val_accuracy: 0.5876
# Epoch 96/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4214 - accuracy: 1.0000 - val_loss: 1.6706 - val_accuracy: 0.5979
# Epoch 97/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4174 - accuracy: 1.0000 - val_loss: 1.6699 - val_accuracy: 0.5979
# Epoch 98/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4118 - accuracy: 1.0000 - val_loss: 1.6693 - val_accuracy: 0.5979
# Epoch 99/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4078 - accuracy: 1.0000 - val_loss: 1.6532 - val_accuracy: 0.5979
# Epoch 100/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4032 - accuracy: 1.0000 - val_loss: 1.6417 - val_accuracy: 0.5876

# %%
plot_loss(history_baseline.history)

# %%
y_train_baselinePred_probs = np.array(baseline_model.predict(X_train_pt))[:,1]
y_test_baselinePred_probs = np.array(baseline_model.predict(X_test_pt))[:,1]

y_train_baselinePred = np.where(y_train_baselinePred_probs > 0.5, 1, 0)
y_test_baselinePred = np.where(y_test_baselinePred_probs > 0.5, 1, 0)

bY_train_true_pfs = bY_train_pfs_oneHot[:,1]
bY_test_true_pfs = bY_test_pfs_oneHot[:,1]

print(y_train_transferPred.shape, y_test_transferPred.shape)
print(bY_train_true_pfs.shape, bY_test_true_pfs.shape)
# Out:
# (313,) (142,)
# (313,) (142,)

# %% [markdown]
# ## Calculate and display metrics

# %%
def get_stats(true_pfs,pred_pfs):
    metrics = [accuracy_score, precision_score, recall_score, f1_score]
    return([np.round(metric(true_pfs, pred_pfs),2) for metric in metrics])

# %%
val_stats_baseline = get_stats(bY_test_true_pfs, y_test_baselinePred)
auc_baseline = np.round(roc_auc_score(bY_test_true_pfs, y_test_baselinePred_probs),2)

val_stats_transfer = get_stats(bY_test_true_pfs, y_test_transferPred)
auc_transfer = np.round(roc_auc_score(bY_test_true_pfs, y_test_transferPred_probs),2)

results_df = (pd.DataFrame({'Experiment': ['Baseline','CRISPR'],
                        'AUC': [auc_baseline,auc_transfer],
                      'Accuracy': [val_stats_baseline[0],val_stats_transfer[0]],
                            'F1': [val_stats_baseline[3],val_stats_transfer[3]],
                      'Precision': [val_stats_baseline[1],val_stats_transfer[1]],
                      'Recall': [val_stats_baseline[2],val_stats_transfer[2]]},
                      index=[0,1]))

display(results_df)
# Out:
#   Experiment   AUC  Accuracy    F1  Precision  Recall
# 0   Baseline  0.61      0.61  0.68       0.63    0.74
# 1     CRISPR  0.53      0.61  0.74       0.59    0.99
